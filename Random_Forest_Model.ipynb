# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeev2712/repo1_gen/blob/master/Random_Forest_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
import talib
# Out:
# --2022-06-25 06:25:53--  http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# Resolving prdownloads.sourceforge.net (prdownloads.sourceforge.net)... 204.68.111.105
# Connecting to prdownloads.sourceforge.net (prdownloads.sourceforge.net)|204.68.111.105|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2022-06-25 06:25:53--  http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Reusing existing connection to prdownloads.sourceforge.net:80.
# HTTP request sent, awaiting response... 302 Found
# Location: http://netix.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2022-06-25 06:25:53--  http://netix.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# ...

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 27.5 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
from datetime import date
import matplotlib
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px
# %matplotlib inline
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid
from sklearn import metrics
# %matplotlib inline

# %%
import yfinance as yf

# %%
ticker= "HINDUNILVR.NS"
stock_Hul = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_Hul.tail()

feature_names_Hul = []
for n in [14, 30, 50, 200]:
    stock_Hul['ma' + str(n)] = talib.SMA(stock_Hul['Adj Close'].values, timeperiod=n)
    stock_Hul['rsi' + str(n)] = talib.RSI(stock_Hul['Adj Close'].values, timeperiod=n)

    feature_names_Hul = feature_names_Hul + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_Hul['Volume_1d_change'] = stock_Hul['Volume'].pct_change()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#stock_Hul['5d_future_close'] = stock_Hul['Adj Close'].shift(-5)
#stock_Hul['5d_close_future_pct'] = stock_Hul['5d_future_close'].pct_change(5)

#stock_Hul.dropna(inplace=True)

stock_Hul.tail()

# %%
#from google.colab import files
#stock_Hul.to_csv('Stockhul.csv', sep='\t', encoding='utf-8')

#files.download('Stockhul.csv')







#from google.colab import files
files.download("Stockhul.csv")

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
ticker= "ADANIPORTS.NS"
stock_Adani = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_Adani.tail()

feature_names_Adani = []
for n in [14, 30, 50, 200]:
    stock_Adani['ma' + str(n)] = talib.SMA(stock_Adani['Adj Close'].values, timeperiod=n)
    stock_Adani['rsi' + str(n)] = talib.RSI(stock_Adani['Adj Close'].values, timeperiod=n)

    feature_names_Adani = feature_names_Adani + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_Adani['Volume_1d_change'] = stock_Adani['Volume'].pct_change()

stock_Adani['5d_future_close'] = stock_Adani['Adj Close'].shift(-5)
stock_Adani['5d_close_future_pct'] = stock_Adani['5d_future_close'].pct_change(5)

stock_Adani.dropna(inplace=True)

stock_Adani.tail()




from google.colab import files
stock_Adani.to_csv('StockAdani.csv', sep='\t', encoding='utf-8')

files.download('StockAdani.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "ASIANPAINT.NS"
stock_Asian = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_Asian.tail()

feature_names_Asian = []
for n in [14, 30, 50, 200]:
    stock_Asian['ma' + str(n)] = talib.SMA(stock_Asian['Adj Close'].values, timeperiod=n)
    stock_Asian['rsi' + str(n)] = talib.RSI(stock_Asian['Adj Close'].values, timeperiod=n)

    feature_names_Asian = feature_names_Asian + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_Asian['Volume_1d_change'] = stock_Asian['Volume'].pct_change()

stock_Asian['5d_future_close'] = stock_Asian['Adj Close'].shift(-5)
stock_Asian['5d_close_future_pct'] = stock_Asian['5d_future_close'].pct_change(5)

stock_Asian.dropna(inplace=True)

stock_Asian.tail()




from google.colab import files
stock_Asian.to_csv('StockAsian.csv', sep='\t', encoding='utf-8')

files.download('StockAsian.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "BHARTIARTL.NS"
stock_Bharti = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_Bharti.tail()

feature_names_Bharti = []
for n in [14, 30, 50, 200]:
    stock_Bharti['ma' + str(n)] = talib.SMA(stock_Bharti['Adj Close'].values, timeperiod=n)
    stock_Bharti['rsi' + str(n)] = talib.RSI(stock_Bharti['Adj Close'].values, timeperiod=n)

    feature_names_Bharti = feature_names_Bharti + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_Bharti['Volume_1d_change'] = stock_Bharti['Volume'].pct_change()

stock_Bharti['5d_future_close'] = stock_Bharti['Adj Close'].shift(-5)
stock_Bharti['5d_close_future_pct'] = stock_Bharti['5d_future_close'].pct_change(5)

stock_Bharti.dropna(inplace=True)

stock_Bharti.tail()




from google.colab import files
stock_Bharti.to_csv('StockBharti.csv', sep='\t', encoding='utf-8')

files.download('StockBharti.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "NTPC.NS"
stock_NTPC = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_NTPC.tail()

feature_names_NTPC = []
for n in [14, 30, 50, 200]:
    stock_NTPC['ma' + str(n)] = talib.SMA(stock_NTPC['Adj Close'].values, timeperiod=n)
    stock_NTPC['rsi' + str(n)] = talib.RSI(stock_NTPC['Adj Close'].values, timeperiod=n)

    feature_names_NTPC = feature_names_NTPC + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_NTPC['Volume_1d_change'] = stock_NTPC['Volume'].pct_change()

stock_NTPC['5d_future_close'] = stock_NTPC['Adj Close'].shift(-5)
stock_NTPC['5d_close_future_pct'] = stock_NTPC['5d_future_close'].pct_change(5)

stock_NTPC.dropna(inplace=True)

stock_NTPC.tail()




from google.colab import files
stock_NTPC.to_csv('StockNTPC.csv', sep='\t', encoding='utf-8')

files.download('StockNTPC.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "RELIANCE.NS"
stock_Rel = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_Rel.tail()

feature_names_Rel = []
for n in [14, 30, 50, 200]:
    stock_Rel['ma' + str(n)] = talib.SMA(stock_Rel['Adj Close'].values, timeperiod=n)
    stock_Rel['rsi' + str(n)] = talib.RSI(stock_Rel['Adj Close'].values, timeperiod=n)

    feature_names_Rel = feature_names_Rel + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_Rel['Volume_1d_change'] = stock_Rel['Volume'].pct_change()

stock_Rel['5d_future_close'] = stock_Rel['Adj Close'].shift(-5)
stock_Rel['5d_close_future_pct'] = stock_Rel['5d_future_close'].pct_change(5)

stock_Rel.dropna(inplace=True)

stock_Rel.tail()




from google.colab import files
stock_Rel.to_csv('StockRel.csv', sep='\t', encoding='utf-8')

files.download('StockRel.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "SBIN.NS"
stock_SBI = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_SBI.tail()

feature_names_SBI = []
for n in [14, 30, 50, 200]:
    stock_SBI['ma' + str(n)] = talib.SMA(stock_SBI['Adj Close'].values, timeperiod=n)
    stock_SBI['rsi' + str(n)] = talib.RSI(stock_SBI['Adj Close'].values, timeperiod=n)

    feature_names_SBI = feature_names_SBI + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_SBI['Volume_1d_change'] = stock_SBI['Volume'].pct_change()

stock_SBI['5d_future_close'] = stock_SBI['Adj Close'].shift(-5)
stock_SBI['5d_close_future_pct'] = stock_SBI['5d_future_close'].pct_change(5)

stock_SBI.dropna(inplace=True)

stock_SBI.tail()




from google.colab import files
stock_SBI.to_csv('StockSBI.csv', sep='\t', encoding='utf-8')

files.download('StockSBI.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "SUNPHARMA.NS"
stock_Sun = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_Sun.tail()

feature_names_Sun = []
for n in [14, 30, 50, 200]:
    stock_Sun['ma' + str(n)] = talib.SMA(stock_Sun['Adj Close'].values, timeperiod=n)
    stock_Sun['rsi' + str(n)] = talib.RSI(stock_Sun['Adj Close'].values, timeperiod=n)

    feature_names_Sun = feature_names_Sun + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_Sun['Volume_1d_change'] = stock_Sun['Volume'].pct_change()

stock_Sun['5d_future_close'] = stock_Sun['Adj Close'].shift(-5)
stock_Sun['5d_close_future_pct'] = stock_Sun['5d_future_close'].pct_change(5)

stock_Sun.dropna(inplace=True)

stock_Sun.tail()




from google.colab import files
stock_Sun.to_csv('StockSun.csv', sep='\t', encoding='utf-8')

files.download('StockSun.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "TCS.NS"
stock_TCS = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_TCS.tail()

feature_names_TCS = []
for n in [14, 30, 50, 200]:
    stock_TCS['ma' + str(n)] = talib.SMA(stock_TCS['Adj Close'].values, timeperiod=n)
    stock_TCS['rsi' + str(n)] = talib.RSI(stock_TCS['Adj Close'].values, timeperiod=n)

    feature_names_TCS = feature_names_TCS + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_TCS['Volume_1d_change'] = stock_TCS['Volume'].pct_change()

stock_TCS['5d_future_close'] = stock_TCS['Adj Close'].shift(-5)
stock_TCS['5d_close_future_pct'] = stock_TCS['5d_future_close'].pct_change(5)

stock_TCS.dropna(inplace=True)

stock_TCS.tail()




from google.colab import files
stock_TCS.to_csv('StockTCS.csv', sep='\t', encoding='utf-8')

files.download('StockTCS.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "ULTRACEMCO.NS"
stock_ULTRA = yf.download(ticker, start="2017-01-04", end="2022-06-20")###Past 5 years data Train sample
stock_ULTRA.tail()

feature_names_ULTRA = []
for n in [14, 30, 50, 200]:
    stock_ULTRA['ma' + str(n)] = talib.SMA(stock_ULTRA['Adj Close'].values, timeperiod=n)
    stock_ULTRA['rsi' + str(n)] = talib.RSI(stock_ULTRA['Adj Close'].values, timeperiod=n)

    feature_names_ULTRA = feature_names_ULTRA + ['ma' + str(n), 'rsi' + str(n)]
	
	
stock_ULTRA['Volume_1d_change'] = stock_ULTRA['Volume'].pct_change()

stock_ULTRA['5d_future_close'] = stock_ULTRA['Adj Close'].shift(-5)
stock_ULTRA['5d_close_future_pct'] = stock_ULTRA['5d_future_close'].pct_change(5)

stock_ULTRA.dropna(inplace=True)

stock_ULTRA.tail()




from google.colab import files
stock_ULTRA.to_csv('StockULTRA.csv', sep='\t', encoding='utf-8')

files.download('StockULTRA.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker= "HINDUNILVR.NS"
stock_Hul = yf.download(ticker, start="2017-02-04", end="2022-02-04")###Past 5 years data Train sample
stock_Hul.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-28  2294.600098  2318.699951  2278.050049  2283.550049  2243.529297
# 2022-01-31  2290.000000  2311.850098  2271.000000  2273.750000  2233.901123
# 2022-02-01  2303.300049  2320.000000  2278.399902  2305.649902  2265.241699
# 2022-02-02  2324.100098  2333.000000  2296.550049  2327.899902  2287.101807
# 2022-02-03  2329.000000  2331.949951  2290.000000  2298.149902  2257.873291
#
#              Volume
# Date
# 2022-01-28  1967721
# 2022-01-31  1639875
# 2022-02-01  1270508
# 2022-02-02  1246111
# 2022-02-03  1448039

# %%
feature_names_Hul = []
for n in [14, 30, 50, 200]:
    stock_Hul['ma' + str(n)] = talib.SMA(stock_Hul['Adj Close'].values, timeperiod=n)
    stock_Hul['rsi' + str(n)] = talib.RSI(stock_Hul['Adj Close'].values, timeperiod=n)

    feature_names_Hul = feature_names_Hul + ['ma' + str(n), 'rsi' + str(n)]

# %%
stock_Hul.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-06  850.049988  862.000000  850.000000  860.549988  786.830750
# 2017-02-07  863.000000  863.299988  851.000000  855.250000  781.984741
# 2017-02-08  859.900024  859.900024  847.349976  852.950012  779.881714
# 2017-02-09  856.000000  856.099976  843.500000  850.750000  777.870300
# 2017-02-10  848.250000  858.400024  847.650024  850.900024  778.007446
#
#              Volume  ma14  rsi14  ma30  rsi30  ma50  rsi50  ma200  rsi200
# Date
# 2017-02-06  1007603   NaN    NaN   NaN    NaN   NaN    NaN    NaN     NaN
# 2017-02-07   866921   NaN    NaN   NaN    NaN   NaN    NaN    NaN     NaN
# 2017-02-08   995337   NaN    NaN   NaN    NaN   NaN    NaN    NaN     NaN
# 2017-02-09   884351   NaN    NaN   NaN    NaN   NaN    NaN    NaN     NaN
# 2017-02-10   648644   NaN    NaN   NaN    NaN   NaN    NaN    NaN     NaN

# %%
stock_Hul['Volume_1d_change'] = stock_Hul['Volume'].pct_change()

volume_features = ['Volume_1d_change']
feature_names_Hul.extend(volume_features)

# %%
stock_Hul['5d_future_close'] = stock_Hul['Adj Close'].shift(-5)
stock_Hul['5d_close_future_pct'] = stock_Hul['5d_future_close'].pct_change(5)

# %%
stock_Hul.dropna(inplace=True)

X = stock_Hul[feature_names_Hul]
y = stock_Hul['5d_close_future_pct']

train_size = int(0.85 * y.shape[0])
X_train = X[:train_size]
y_train = y[:train_size]
X_test = X[train_size:]
y_test = y[train_size:]

# %%
grid = {'n_estimators': [200,500], 'max_depth': [3,5], 'max_features': [4, 8], 'random_state': [42]}
test_scores = []

rf_model = RandomForestRegressor()

for g in ParameterGrid(grid):
    rf_model.set_params(**g) 
    rf_model.fit(X_train, y_train)
    test_scores.append(rf_model.score(X_test, y_test))

best_index = np.argmax(test_scores)
print(test_scores[best_index], ParameterGrid(grid)[best_index])
# Out:
# -1.7599717167164428 {'random_state': 42, 'n_estimators': 200, 'max_features': 4, 'max_depth': 3}

# %%
rf_model = RandomForestRegressor(n_estimators=200, max_depth=3, max_features=4, random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

y_pred_series = pd.Series(y_pred, index=y_test.index)
y_pred_series.plot()
plt.ylabel("Predicted 5 Day Close Price Change Percent")
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.03592516824677338
# Mean Squared Error: 0.002118714488230933
# Root Mean Squared Error: 0.046029495850279885

# %%
y_pred
# Out:
# array([ 0.00438768,  0.0038704 , -0.01027647, -0.0126042 , -0.01083384,
#        -0.00826521, -0.01100182,  0.00351763,  0.00279969, -0.00789213,
#         0.00136724, -0.00821852, -0.00854491, -0.0115468 ,  0.0025554 ,
#        -0.00695166,  0.00363355,  0.00341856,  0.00334396,  0.00390588,
#         0.00421257,  0.00419189,  0.00428717,  0.00457147,  0.00392572,
#         0.00436436,  0.00436775,  0.00463903,  0.00485476,  0.00436775,
#         0.00503906,  0.00536529,  0.00574804,  0.00444583,  0.00435871,
#         0.00436775,  0.00446868,  0.00450163,  0.00452231,  0.00444583,
#         0.00452043,  0.00473077,  0.00369343,  0.00344182,  0.00322683,
#        -0.01489344, -0.0147837 , -0.01456683, -0.01498483, -0.01506225,
#        -0.01504071, -0.0150492 , -0.01536462, -0.01517954, -0.01658399,
#        -0.01517954, -0.01550312, -0.0153303 , -0.01558992, -0.01631676,
#        -0.01537483, -0.01494264, -0.01461989, -0.0146754 , -0.01511249,
# ...

# %%
y_test.tail()
# Out:
# Date
# 2021-09-03    0.007103
# 2021-09-06   -0.006491
# 2021-09-07   -0.000810
# 2021-09-08   -0.011657
# 2021-09-09   -0.031452
#                 ...
# 2022-01-20    0.009616
# 2022-01-21   -0.022211
# 2022-01-24    0.009214
# 2022-01-25    0.000279
# 2022-01-27    0.001220
# Name: 5d_close_future_pct, Length: 100, dtype: float64

# %%
importances = rf_model.feature_importances_
sorted_index = np.argsort(importances)[::-1]
x_values = range(len(importances))
labels = np.array(feature_names_Hul)[sorted_index]
plt.bar(x_values, importances[sorted_index], tick_label=labels)
plt.xticks(rotation=90)
plt.show()

# %%
# !pip install pandas_ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 115 kB 7.8 MB/s
# ...
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218923 sha256=1cae6cebeaea131716ed46b4edd2d0c5407d8bdb97a3ff9ac6fff6167c4bd87e
#   Stored in directory: /root/.cache/pip/wheels/0b/81/f0/cca85757840e4616a2c6b9fe12569d97d324c27cac60724c58
# Successfully built pandas-ta
# ...

# %%
import pandas_ta as ta

# %%
help(ta.smi)
# Out:
# Help on function smi in module pandas_ta.momentum.smi:
#
# smi(close, fast=None, slow=None, signal=None, scalar=None, offset=None, **kwargs)
#     SMI Ergodic Indicator (SMI)
#
#     The SMI Ergodic Indicator is the same as the True Strength Index (TSI) developed
#     by William Blau, except the SMI includes a signal line. The SMI uses double
#     moving averages of price minus previous price over 2 time frames. The signal
#     line, which is an EMA of the SMI, is plotted to help trigger trading signals.
#     The trend is bullish when crossing above zero and bearish when crossing below
#     zero. This implementation includes both the SMI Ergodic Indicator and SMI
#     Ergodic Oscillator.
#
#     Sources:
#         https://www.motivewave.com/studies/smi_ergodic_indicator.htm
#         https://www.tradingview.com/script/Xh5Q0une-SMI-Ergodic-Oscillator/
#         https://www.tradingview.com/script/cwrgy4fw-SMIIO/
#
#     Calculation:
#         Default Inputs:
# ...
